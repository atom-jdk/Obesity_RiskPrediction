# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.27.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.2)

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
#from ydata_profiling import ProfileReport
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
categorical_cols = ['Gender', 'family_history_with_overweight', 'FAVC','CAEC','SMOKE','SCC','CALC','MTRANS']
target_col = ['WeightCategory']

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}

for col in categorical_cols:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col].astype(str))  # fit on train
    test[col] = le.transform(test[col].astype(str))        # transform on test
    label_encoders[col] = le

# Target encoding
target_encoder = LabelEncoder()
train[target_col[0]] = target_encoder.fit_transform(train[target_col[0]].astype(str))
#test[target_col[0]] = target_encoder.transform(test[target_col[0]].astype(str))

# %%
x = train.drop('WeightCategory', axis=1)
x = x.drop('id', axis=1)
y = train['WeightCategory']

# %%
a = test['id']
z = test.drop('id', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.0)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 7.7 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.5.0

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 570, 700),
        'max_depth': trial.suggest_int('max_depth', 5, 8),
        'learning_rate': trial.suggest_float('learning_rate', 0.0475, 0.0495, step=0.0001),
        'subsample': trial.suggest_float('subsample', 0.518, 0.538),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.407, 0.5),
        'gamma': trial.suggest_float('gamma', 0.590, 0.896),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 4),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.25, 0.6),
        'reg_lambda': trial.suggest_float('reg_lambda', 1.4, 2.8),
        'random_state': 42,
        'eval_metric': 'mlogloss',
        'use_label_encoder': False,
        'n_jobs': -1
    }

    model = XGBClassifier(**params)
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    scores = cross_validate(
        model,
        X_train,
        y_train,
        cv=cv,
        scoring='accuracy',
        n_jobs=-1,
        return_train_score=False
    )

    return scores['test_score'].mean()

# %% [markdown]
# 2025-10-24 10:46:38,769] Trial 171 finished with value: 0.9097859886592282 and parameters: {'n_estimators': 591, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5294362645863591, 'colsample_bytree': 0.40810876257770307, 'gamma': 0.5914696370814657, 'min_child_weight': 1, 'reg_alpha': 0.35196879936563696, 'reg_lambda': 1.5459952657701226}. Best is trial 171 with value: 0.9097859886592282.

# %% [markdown]
# 2025-10-24 14:19:29,939] Trial 211 finished with value: 0.907210989185313 and parameters: {'n_estimators': 579, 'max_depth': 8, 'learning_rate': 0.0487, 'subsample': 0.5360427193925438, 'colsample_bytree': 0.4101385332050717, 'gamma': 0.5915864928857023, 'min_child_weight': 1, 'reg_alpha': 0.44530608551240997, 'reg_lambda': 2.099943285494622}. Best is trial 211 with value: 0.907210989185313.

# %% [markdown]
# [I 2025-10-24 19:09:23,089] Trial 171 finished with value: 0.9072915044571532 and parameters: {'n_estimators': 603, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5256748066272386, 'colsample_bytree': 0.4120439796865733, 'gamma': 0.5956033365053646, 'min_child_weight': 1, 'reg_alpha': 0.5431248836578476, 'reg_lambda': 2.6978553976423196}. Best is trial 171 with value: 0.9072915044571532.

# %%
import optuna
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from xgboost import XGBClassifier
from scipy import stats

# -----------------------------
# 1) Preprocessing functions
# -----------------------------
def add_derived_features(df):
    df = df.copy()
    if 'Weight' in df.columns and 'Height' in df.columns:
        df['Height_m'] = df['Height'].apply(lambda h: h/100.0 if h>3 else h)
        df['BMI'] = df['Weight'] / (df['Height_m'] ** 2 + 1e-9)
    if 'FCVC' in df.columns and 'FAF' in df.columns and 'CH2O' in df.columns:
        df['Healthy_Lifestyle_Score'] = 0.3*df['FCVC'] + 0.3*df['FAF'] + 0.4*df['CH2O']
    if 'BMI' in df.columns and 'PhysicalActivity' in df.columns:
        df['BMI_x_activity'] = df['BMI'] * df['PhysicalActivity']
    if 'CH2O' in df.columns and 'NMeals' in df.columns:
        df['Water_per_meal'] = df['CH2O'] / (df['NMeals'] + 1e-9)
    if 'TechUse' in df.columns and 'PhysicalActivity' in df.columns:
        df['Activity_to_Tech'] = df['PhysicalActivity'] / (df['TechUse'] + 1e-9)
    return df

def log_transform_skewed(df, numeric_cols):
    df = df.copy()
    for col in numeric_cols:
        if (df[col] > 0).all():
            skew = stats.skew(df[col].dropna())
            if abs(skew) > 1.0:
                df[col] = np.log1p(df[col])
    return df

def prepare_Xy(X):
    Xp = add_derived_features(X)
    numeric_cols = Xp.select_dtypes(include=[np.number]).columns.tolist()
    cat_cols = Xp.select_dtypes(include=['object','category']).columns.tolist()
    Xp = log_transform_skewed(Xp, numeric_cols)
    return Xp, numeric_cols, cat_cols

# -----------------------------
# 2) Build pipeline
# -----------------------------
def make_model_pipeline(params, numeric_cols, cat_cols):
    num_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ])
    cat_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('ohe', OneHotEncoder(handle_unknown='ignore'))
    ])
    preproc = ColumnTransformer([
        ('num', num_transformer, numeric_cols),
        ('cat', cat_transformer, cat_cols)
    ], remainder='drop')

    xgb = XGBClassifier(
        objective='multi:softprob',
        use_label_encoder=False,
        eval_metric='mlogloss',
        n_jobs=-1,
        **params
    )

    pipe = Pipeline([
        ('preproc', preproc),
        ('model', xgb)
    ])
    return pipe

# -----------------------------
# 3) Prepare data once
# -----------------------------
Xp_full, numeric_cols, cat_cols = prepare_Xy(X_train)  # X_train defined outside
y_full = y_train  # just alias

# -----------------------------
# 4) Optuna objective
# -----------------------------
def objective(trial):
    booster = trial.suggest_categorical('booster', ['gbtree','dart'])
    grow_policy = trial.suggest_categorical('grow_policy', ['depthwise','lossguide'])

    params = {
        'n_estimators': trial.suggest_int('n_estimators', 300, 600),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 1e-3, 0.2, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.5, 5.0),
        'booster': booster,
        'grow_policy': grow_policy,
        'verbosity': 0
    }

    pipe = make_model_pipeline(params, numeric_cols, cat_cols)
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = cross_validate(pipe, Xp_full, y_full, cv=cv, scoring='accuracy', n_jobs=1)
    return scores['test_score'].mean()

# -----------------------------
# 5) Run Optuna study
# -----------------------------
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, show_progress_bar=True)

print("Best trial params:", study.best_trial.params)
print("Best trial accuracy:", study.best_value)
# Out:
# [I 2025-10-25 07:42:22,833] A new study created in memory with name: no-name-aa4b9aa0-1d55-48a4-adee-00318d6ef097
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-25 07:42:55,949] Trial 0 finished with value: 0.8940125543215838 and parameters: {'booster': 'gbtree', 'grow_policy': 'lossguide', 'n_estimators': 598, 'max_depth': 8, 'learning_rate': 0.005165675722849387, 'subsample': 0.5786021354250325, 'colsample_bytree': 0.7669456973305728, 'gamma': 0.2515724524363616, 'min_child_weight': 6, 'reg_alpha': 0.16741539875601652, 'reg_lambda': 0.9394583934569212}. Best is trial 0 with value: 0.8940125543215838.
# [I 2025-10-25 07:43:12,235] Trial 1 finished with value: 0.9007725736359248 and parameters: {'booster': 'gbtree', 'grow_policy': 'lossguide', 'n_estimators': 386, 'max_depth': 7, 'learning_rate': 0.05171214923253784, 'subsample': 0.5531447366270147, 'colsample_bytree': 0.7399632883884177, 'gamma': 0.18066089612211322, 'min_child_weight': 9, 'reg_alpha': 0.9882158546818965, 'reg_lambda': 3.5068395053606967}. Best is trial 1 with value: 0.9007725736359248.
# [I 2025-10-25 08:06:13,677] Trial 2 finished with value: 0.8939320779011749 and parameters: {'booster': 'dart', 'grow_policy': 'depthwise', 'n_estimators': 363, 'max_depth': 12, 'learning_rate': 0.00507557700075349, 'subsample': 0.9293948015540726, 'colsample_bytree': 0.5126698162210653, 'gamma': 0.16287823174237603, 'min_child_weight': 5, 'reg_alpha': 0.3492396432157744, 'reg_lambda': 1.16801604943271}. Best is trial 1 with value: 0.9007725736359248.
# [I 2025-10-25 08:21:29,210] Trial 3 finished with value: 0.8771125060357315 and parameters: {'booster': 'dart', 'grow_policy': 'depthwise', 'n_estimators': 328, 'max_depth': 3, 'learning_rate': 0.00835714131227118, 'subsample': 0.9620478903888268, 'colsample_bytree': 0.45563671520304344, 'gamma': 0.030920341941387486, 'min_child_weight': 8, 'reg_alpha': 0.21826635087157986, 'reg_lambda': 3.2793427768717485}. Best is trial 1 with value: 0.9007725736359248.
# [I 2025-10-25 08:21:44,428] Trial 4 finished with value: 0.898841139546113 and parameters: {'booster': 'gbtree', 'grow_policy': 'depthwise', 'n_estimators': 433, 'max_depth': 8, 'learning_rate': 0.01259250451917104, 'subsample': 0.8858616955015914, 'colsample_bytree': 0.4290692445860549, 'gamma': 0.9820375890803588, 'min_child_weight': 10, 'reg_alpha': 0.47739144992382765, 'reg_lambda': 2.2014403974896086}. Best is trial 1 with value: 0.9007725736359248.
# [I 2025-10-25 08:38:01,041] Trial 5 finished with value: 0.896587799774666 and parameters: {'booster': 'dart', 'grow_policy': 'lossguide', 'n_estimators': 315, 'max_depth': 12, 'learning_rate': 0.015464233730119426, 'subsample': 0.5145672165157243, 'colsample_bytree': 0.6650343353894288, 'gamma': 0.2051659921211898, 'min_child_weight': 5, 'reg_alpha': 0.579689879532372, 'reg_lambda': 3.963778332420185}. Best is trial 1 with value: 0.9007725736359248.
# [I 2025-10-25 09:13:35,966] Trial 6 finished with value: 0.8812168034765814 and parameters: {'booster': 'dart', 'grow_policy': 'depthwise', 'n_estimators': 504, 'max_depth': 3, 'learning_rate': 0.007165732414630168, 'subsample': 0.9818820879777344, 'colsample_bytree': 0.3699271684058897, 'gamma': 0.4575464034248614, 'min_child_weight': 6, 'reg_alpha': 0.3829009046313585, 'reg_lambda': 0.7668354164207478}. Best is trial 1 with value: 0.9007725736359248.
# [I 2025-10-25 09:43:47,668] Trial 7 finished with value: 0.8865282472235635 and parameters: {'booster': 'dart', 'grow_policy': 'lossguide', 'n_estimators': 462, 'max_depth': 3, 'learning_rate': 0.01343882615434794, 'subsample': 0.9222901917106671, 'colsample_bytree': 0.8705156178786457, 'gamma': 0.9968849983140959, 'min_child_weight': 3, 'reg_alpha': 0.5034168977247869, 'reg_lambda': 3.140440223280421}. Best is trial 1 with value: 0.9007725736359248.
and parameters: {'booster': 'gbtree', 'grow_policy': 'lossguide', 'n_estimators': 499, 'max_depth': 4, 'learning_rate': 0.04016962846779025, 'subsample': 0.5945553614070201, 'colsample_bytree': 0.3156188443560516, 'gamma': 0.7127176086242387, 'min_child_weight': 4, 'reg_alpha': 0.8681112590325322, 'reg_lambda': 2.4058499731366876}. Best is trial 20 with value: 0.9034282955094156.
# [I 2025-10-25 09:47:37,782] Trial 24 finished with value: 0.9005311443746983 and parameters: {'booster': 'gbtree', 'grow_policy': 'lossguide', 'n_estimators': 447, 'max_depth': 4, 'learning_rate': 0.03529162330312704, 'subsample': 0.5121033701831741, 'colsample_bytree': 0.3384215499269692, 'gamma': 0.7239225531536684, 'min_child_weight': 4, 'reg_alpha': 0.8096805389888433, 'reg_lambda': 2.4599515513842025}. Best is trial 20 with value: 0.9034282955094156.
# [I 2025-10-25 09:47:47,490] Trial 25 finished with value: 0.9038306776114599 and parameters: {'booster': 'gbtree', 'grow_policy': 'lossguide', 'n_estimators': 498, 'max_depth': 4, 'learning_rate': 0.1412660549529865, 'subsample': 0.5820268272799902, 'colsample_bytree': 0.3095493320533369, 'gamma': 0.9138629243653549, 'min_child_weight': 4, 'reg_alpha': 0.9086118266246435, 'reg_lambda': 1.6268603925913823}. Best is trial 25 with value: 0.9038306776114599.
# [I 2025-10-25 10:18:58,409] Trial 26 finished with value: 0.9020601963624658 and parameters: {'booster': 'dart', 'grow_policy': 'lossguide', 'n_estimators': 473, 'max_depth': 5, 'learning_rate': 0.1303922514024219, 'subsample': 0.5624117512379238, 'colsample_bytree': 0.3905284216632466, 'gamma': 0.9085238716630646, 'min_child_weight': 5, 'reg_alpha': 0.5996645193441676, 'reg_lambda': 1.1663057859725572}. Best is trial 25 with value: 0.9038306776114599.
# [I 2025-10-25 10:19:14,275] Trial 27 finished with value: 0.880492515692902 and parameters: {'booster': 'gbtree', 'grow_policy': 'lossguide', 'n_estimators': 584, 'max_depth': 4, 'learning_rate': 0.001990539568333665, 'subsample': 0.5381681330954188, 'colsample_bytree': 0.3054890225536012, 'gamma': 0.9049692366910543, 'min_child_weight': 3, 'reg_alpha': 0.9272089261402326, 'reg_lambda': 1.7779159605924217}. Best is trial 25 with value: 0.9038306776114599.
# [I 2025-10-25 10:19:23,040] Trial 28 finished with value: 0.9023821020441011 and parameters: {'booster': 'gbtree', 'grow_policy': 'lossguide', 'n_estimators': 407, 'max_depth': 7, 'learning_rate': 0.12881104840491042, 'subsample': 0.7204954618241305, 'colsample_bytree': 0.40477617479869427, 'gamma': 0.9394176056798931, 'min_child_weight': 7, 'reg_alpha': 0.7986801836760196, 'reg_lambda': 1.2824575513289844}. Best is trial 25 with value: 0.9038306776114599.
# [I 2025-10-25 10:19:38,667] Trial 29 finished with value: 0.9026235313053276 and parameters: {'booster': 'gbtree', 'grow_policy': 'lossguide', 'n_estimators': 600, 'max_depth': 5, 'learning_rate': 0.05470676560920751, 'subsample': 0.5963063664211442, 'colsample_bytree': 0.4720347835673717, 'gamma': 0.7629417413583909, 'min_child_weight': 6, 'reg_alpha': 0.6503017760923521, 'reg_lambda': 0.8038243296566634}. Best is trial 25 with value: 0.9038306776114599.
# [I 2025-10-25 10:19:54,119] Trial 30 finished with value: 0.9026235313053276 and parameters: {'booster': 'gbtree', 'grow_policy': 'lossguide', 'n_estimators':
and parameters: {'booster': 'dart', 'grow_policy': 'depthwise', 'n_estimators': 376, 'max_depth': 11, 'learning_rate': 0.07312921396086094, 'subsample': 0.6764366231550686, 'colsample_bytree': 0.3935661572675423, 'gamma': 0.29696067660154724, 'min_child_weight': 2, 'reg_alpha': 0.48425931078553863, 'reg_lambda': 4.042472633544493}. Best is trial 52 with value: 0.9047159182359569.
# [I 2025-10-25 16:15:00,989] Trial 57 finished with value: 0.9029454369869628 and parameters: {'booster': 'dart', 'grow_policy': 'depthwise', 'n_estimators': 474, 'max_depth': 8, 'learning_rate': 0.15978417221795818, 'subsample': 0.7234259698480738, 'colsample_bytree': 0.331468255363297, 'gamma': 0.8702756929558607, 'min_child_weight': 4, 'reg_alpha': 0.5791074416946875, 'reg_lambda': 2.6684837571153563}. Best is trial 52 with value: 0.9047159182359569.

# %%
storage_name = "sqlite:///xgb_optuna_v1.db"
study = optuna.create_study(
    study_name="xgb_tuning_v4",
    storage=storage_name,
    direction="maximize"
)

# Seed top 3 trials
study.enqueue_trial({
    'n_estimators': 625,
    'max_depth': 8,
    'learning_rate': 0.0486,
    'subsample': 0.5256748066272386,
    'colsample_bytree': 0.4120439796865733,
    'gamma': 0.590603365053646,
    'min_child_weight': 2,
    'reg_alpha': 0.54312,
    'reg_lambda': 2.7
})




study.optimize(objective, n_trials=300, show_progress_bar=True)
# Out:
# [I 2025-10-25 05:06:11,425] A new study created in RDB with name: xgb_tuning_v4
#   0%|          | 0/300 [00:00<?, ?it/s]
# [I 2025-10-25 05:06:37,320] Trial 0 finished with value: 0.9055210425869781 and parameters: {'n_estimators': 625, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5256748066272386, 'colsample_bytree': 0.4120439796865733, 'gamma': 0.590603365053646, 'min_child_weight': 2, 'reg_alpha': 0.54312, 'reg_lambda': 2.7}. Best is trial 0 with value: 0.9055210425869781.
# [I 2025-10-25 05:06:59,973] Trial 1 finished with value: 0.9043942172746859 and parameters: {'n_estimators': 661, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5310233472365982, 'colsample_bytree': 0.4821274854704905, 'gamma': 0.7594675603754767, 'min_child_weight': 3, 'reg_alpha': 0.5965084991146913, 'reg_lambda': 1.84331808971243}. Best is trial 0 with value: 0.9055210425869781.
# [I 2025-10-25 05:07:19,743] Trial 2 finished with value: 0.9057623617813073 and parameters: {'n_estimators': 595, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5323315564766823, 'colsample_bytree': 0.42767251064516315, 'gamma': 0.8281542787423649, 'min_child_weight': 2, 'reg_alpha': 0.2647152846059625, 'reg_lambda': 2.4473353333286068}. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05:07:42,573] Trial 3 finished with value: 0.9051186281000565 and parameters: {'n_estimators': 602, 'max_depth': 7, 'learning_rate': 0.0479, 'subsample': 0.5230043856459661, 'colsample_bytree': 0.4212268695907464, 'gamma': 0.5959986475213859, 'min_child_weight': 3, 'reg_alpha': 0.30206934003441205, 'reg_lambda': 2.1231127375371415}. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05:08:02,711] Trial 4 finished with value: 0.9043943467725096 and parameters: {'n_estimators': 571, 'max_depth': 7, 'learning_rate': 0.0478, 'subsample': 0.5368020696892537, 'colsample_bytree': 0.4468591460227739, 'gamma': 0.7371638437437197, 'min_child_weight': 2, 'reg_alpha': 0.5799978282886619, 'reg_lambda': 2.6791980156325312}. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05
. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05:11:40,366] Trial 14 finished with value: 0.9056820083817465 and parameters: {'n_estimators': 626, 'max_depth': 8, 'learning_rate': 0.0475, 'subsample': 0.5185360249257569, 'colsample_bytree': 0.45693076910880825, 'gamma': 0.8214555225476032, 'min_child_weight': 1, 'reg_alpha': 0.41519010672418744, 'reg_lambda': 2.166359707369588}. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05:12:01,599] Trial 15 finished with value: 0.9054405273151378 and parameters: {'n_estimators': 632, 'max_depth': 8, 'learning_rate': 0.0475, 'subsample': 0.518155287823546, 'colsample_bytree': 0.4615435128603957, 'gamma': 0.8283146946429167, 'min_child_weight': 2, 'reg_alpha': 0.2538244213635643, 'reg_lambda': 1.9719577945403324}. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05:12:23,910] Trial 16 finished with value: 0.9048772765312713 and parameters: {'n_estimators': 648, 'max_depth': 5, 'learning_rate': 0.0475, 'subsample': 0.5188504563947453, 'colsample_bytree': 0.4941319645134616, 'gamma': 0.8094915628244714, 'min_child_weight': 1, 'reg_alpha': 0.39136731242745065, 'reg_lambda': 2.158229408234517}. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05:12:45,113] Trial 17 finished with value: 0.9051186281000565 and parameters: {'n_estimators': 615, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5273394442330076, 'colsample_bytree': 0.4492915407652345, 'gamma': 0.8848197782876648, 'min_child_weight': 2, 'reg_alpha': 0.32538760307314435, 'reg_lambda': 2.474920817758569}. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05:13:06,455] Trial 18 finished with value: 0.905521042586978 and parameters: {'n_estimators': 619, 'max_depth': 8, 'learning_rate': 0.0495, 'subsample': 0.5224201835422582, 'colsample_bytree': 0.46400659207028766, 'gamma': 0.7338106296893065, 'min_child_weight': 1, 'reg_alpha': 0.41955867803345015, 'reg_lambda': 1.6883273680365256}. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05:13:29,780] Trial 19 finished with value: 0.9051184662277769 and parameters: {'n_estimators': 645, 'max_depth': 7, 'learning_rate': 0.048, 'subsample': 0.533187250247096, 'colsample_bytree': 0.4209669283695096, 'gamma': 0.845066266709081, 'min_child_weight': 2, 'reg_alpha': 0.3471908044065227, 'reg_lambda': 2.506723363802891}. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05:13:50,234] Trial 20 finished with value: 0.9051990462485291 and parameters: {'n_estimators': 597, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.526266952941792, 'colsample_bytree': 0.44202738691306875, 'gamma': 0.8073808315032048, 'min_child_weight': 3, 'reg_alpha': 0.5252822392245075, 'reg_lambda': 2.203941460180768}. Best is trial 2 with value: 0.9057623617813073.
# [I 2025-10-25 05:14:11,315] Trial 21 finished with value: 0.9059234246994435 and parameters: {'n_estimators': 584, 'max_depth': 7, 'learning_rate': 0.0483, 'subsample': 0.530413545255552, 'colsample_bytree': 0.42988999806577716, 'gamma': 0.6545117092458841, 'min_child_weight': 1, 'reg_alpha': 0.46941307846564156, 'reg_lambda': 2.005917969512982}. Best is trial 21 with value: 0.9059234246994435.
# [I 2025-10-25 05:14:33,165] Trial 22 finished with value: 0.9057623941557631 and parameters: {'n_estimators': 604, 'max_depth': 7, 'learning_rate': 0.0488, 'subsample': 0.532430975903967, 'colsample_bytree': 0.42235079014883126, 'gamma': 0.6309191584991548, 'min_child_weight': 1, 'reg_alpha': 0.48990326011826596, 'reg_lambda': 1.9720033063340183}. Best is trial 21 with value: 0.9059234246994435.
# [I 2025-10-25 05:14:53,370] Trial 23 finished with value: 0.905038177577128 and parameters: {'n_estimators': 583, 'max_depth': 6, 'learning_rate': 0.0488, 'subsample': 0.5327610576132781, 'colsample_bytree': 0.42313482150977866, 'gamma': 0.6254367269434965, 'min_child_weight': 1, 'reg_alpha': 0.4944006450749491, 'reg_lambda': 2.0180347825565286}. Best is trial 21 with value: 0.9059234246994435.
# [I 2025-10-25 05:15:15,170] Trial 24 finished with value: 0.9051185633511446 and parameters: {'n_estimators': 598, 'max_depth': 7, 'learning_rate': 0.0485, 'subsample': 0.5353169837120884, 'colsample_bytree': 0.41596818050961415, 'gamma': 0.6380171292513803, 'min_child_weight': 2, 'reg_alpha': 0.48618046716474356, 'reg_lambda': 1.8927086235615287}. Best is trial 21 with value: 0.9059234246994435.
# [I 2025-10-25 05:15:35,972] Trial 25 finished with value: 0.9052794967714574 and parameters: {'n_estimators': 606, 'max_depth': 7, 'learning_rate': 0.0483, 'subsample': 0.5319517102715537, 'colsample_bytree': 0.42896127970381137, 'gamma': 0.7065074891877209, 'min_child_weight': 1, 'reg_alpha': 0.4451242984617636, 'reg_lambda': 1.5702313106271837}. Best is trial 21 with value: 0.9059234246994435.
# [I 2025-10-25 05:15:58,062] Trial 26 finished with value: 0.9051185957256006 and parameters: {'n_estimators': 581, 'max_depth': 6, 'learning_rate': 0.0488, 'subsample': 0.5374297888260064, 'colsample_bytree': 0.41598059806201776, 'gamma': 0.648964487753498, 'min_child_weight': 2, 'reg_alpha': 0.4984852067397141, 'reg_lambda': 1.7266767502205165}. Best is trial 21 with value: 0.9059234246994435.
# [I 2025-10-25 05:16:20,689] Trial 27 finished with value: 0.9049575975563761 and parameters: {'n_estimators': 591, 'max_depth': 7, 'learning_rate': 0.0492, 'subsample': 0.5293243303668234, 'colsample_bytree': 0.44210401172355157, 'gamma': 0.6143986319881614, 'min_child_weight': 1, 'reg_alpha': 0.2828448725506698, 'reg_lambda': 2.029104304867952}. Best is trial 21 with value: 0.9059234246994435.
# [I 2025-10-25 05:16:41,081] Trial 28 finished with value: 0.9060037780990043 and parameters: {'n_estimators': 612, 'max_depth': 7, 'learning_rate': 0.0486, 'subsample': 0.5275522766628061, 'colsample_bytree': 0.4070449352213554, 'gamma': 0.7240664213220767, 'min_child_weight': 1, 'reg_alpha': 0.5573083036268116, 'reg_lambda': 1.9352878220284668}. Best is trial 28 with value: 0.9060037780990043.
# [I 2025-10-25 05:17:02,403] Trial 29 finished with value: 0.9049575975563761 and parameters: {'n_estimators': 615, 'max_depth': 6, 'learning_rate': 0.0486, 'subsample': 0.5276087252716929, 'colsample_bytree': 0.4090147339082456, 'gamma': 0.7069431400394967, 'min_child_weight': 1, 'reg_alpha': 0.565022316442374, 'reg_lambda': 1.7063846276387984}. Best is trial 28 with value: 0.9060037780990043.
# [I 2025-10-25 05:17:24,744] Trial 30 finished with value: 0.9056819436328348 and parameters: {'n_estimators': 636, 'max_depth': 7, 'learning_rate': 0.0487, 'subsample': 0.5257731661762465, 'colsample_bytree': 0.4148210671031205, 'gamma': 0.5906151757168314, 'min_child_weight': 1, 'reg_alpha': 0.5507792408301012, 'reg_lambda': 1.9361994230158228}. Best is trial 28 with value: 0.9060037780990043.
# [I 2025-10-25 05:17:45,219] Trial 31 finished with value: 0.905279626269281 and parameters: {'n_estimators': 603, 'max_depth': 7, 'learning_rate': 0.0485, 'subsample': 0.5320242700932762, 'colsample_bytree': 0.42462442597417177, 'gamma': 0.7632611019399318, 'min_child_weight': 2, 'reg_alpha': 0.5216566235984214, 'reg_lambda': 2.0798789532128743}. Best is trial 28 with value: 0.9060037780990043.
# [I 2025-10-25 05:18:06,734] Trial 32 finished with value: 0.9061648086426848 and parameters: {'n_estimators': 612, 'max_depth': 7, 'learning_rate': 0.0483, 'subsample': 0.5348546397272625, 'colsample_bytree': 0.4330439242481882, 'gamma': 0.7196357790192602, 'min_child_weight': 1, 'reg_alpha': 0.47717125491344126, 'reg_lambda': 1.8144131151768972}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:18:28,735] Trial 33 finished with value: 0.9057623941557631 and parameters: {'n_estimators': 622, 'max_depth': 7, 'learning_rate': 0.0482, 'subsample': 0.5345693747853831, 'colsample_bytree': 0.4348150234337718, 'gamma': 0.7228967565440415, 'min_child_weight': 1, 'reg_alpha': 0.4798639686791493, 'reg_lambda': 1.7930863040712683}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:18:50,069] Trial 34 finished with value: 0.9054405273151378 and parameters: {'n_estimators': 611, 'max_depth': 7, 'learning_rate': 0.0486, 'subsample': 0.5301807051442649, 'colsample_bytree': 0.418800350794678, 'gamma': 0.7618724759434771, 'min_child_weight': 1, 'reg_alpha': 0.5090827986497768, 'reg_lambda': 1.6323707587642486}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:19:12,419] Trial 35 finished with value: 0.9059233599505317 and parameters: {'n_estimators': 630, 'max_depth': 7, 'learning_rate': 0.0483, 'subsample': 0.5284659111868484, 'colsample_bytree': 0.41090313608668116, 'gamma': 0.6525552125916118, 'min_child_weight': 1, 'reg_alpha': 0.4360097292464272, 'reg_lambda': 1.888017666001228}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:19:34,799] Trial 36 finished with value: 0.9052795938948253 and parameters: {'n_estimators': 641, 'max_depth': 7, 'learning_rate': 0.0479, 'subsample': 0.5247074303705924, 'colsample_bytree': 0.410941130916319, 'gamma': 0.659402415918624, 'min_child_weight': 1, 'reg_alpha': 0.403010107340657, 'reg_lambda': 1.8638363655494812}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:19:57,947] Trial 37 finished with value: 0.9041528333314448 and parameters: {'n_estimators': 653, 'max_depth': 6, 'learning_rate': 0.0483, 'subsample': 0.5281867784028891, 'colsample_bytree': 0.4122318179134794, 'gamma': 0.6918985260324875, 'min_child_weight': 1, 'reg_alpha': 0.4281076735645727, 'reg_lambda': 1.820297772989606}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:20:19,600] Trial 38 finished with value: 0.9057624265302191 and parameters: {'n_estimators': 623, 'max_depth': 7, 'learning_rate': 0.048, 'subsample': 0.5267370284306843, 'colsample_bytree': 0.4328810335371909, 'gamma': 0.7497292835358277, 'min_child_weight': 3, 'reg_alpha': 0.5449380990575976, 'reg_lambda': 2.7814456817665354}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:20:42,175] Trial 39 finished with value: 0.9055210102125221 and parameters: {'n_estimators': 674, 'max_depth': 7, 'learning_rate': 0.0483, 'subsample': 0.524101596815282, 'colsample_bytree': 0.40712480724987027, 'gamma': 0.7104647011821045, 'min_child_weight': 2, 'reg_alpha': 0.4411876407918566, 'reg_lambda': 2.090458422199131}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:21:06,804] Trial 40 finished with value: 0.9034285520038979 and parameters: {'n_estimators': 630, 'max_depth': 6, 'learning_rate': 0.0484, 'subsample': 0.5233725476642843, 'colsample_bytree': 0.4511975714631376, 'gamma': 0.6112794749243486, 'min_child_weight': 1, 'reg_alpha': 0.5710309389259716, 'reg_lambda': 1.5227362531176003}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:21:29,284] Trial 41 finished with value: 0.9044747325465261 and parameters: {'n_estimators': 625, 'max_depth': 7, 'learning_rate': 0.0479, 'subsample': 0.5266468820001398, 'colsample_bytree': 0.44425878430054044, 'gamma': 0.7365122700149066, 'min_child_weight': 3, 'reg_alpha': 0.5483752265624141, 'reg_lambda': 1.7667799390639487}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:21:50,805] Trial 42 finished with value: 0.9050381775771281 and parameters: {'n_estimators': 638, 'max_depth': 7, 'learning_rate': 0.048100000000000004, 'subsample': 0.5283318481769906, 'colsample_bytree': 0.4340747721741804, 'gamma': 0.7785489636392932, 'min_child_weight': 3, 'reg_alpha': 0.5962308924610966, 'reg_lambda': 2.7781881244495956}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:22:12,394] Trial 43 finished with value: 0.9048771794079036 and parameters: {'n_estimators': 617, 'max_depth': 7, 'learning_rate': 0.0477, 'subsample': 0.5271282934189855, 'colsample_bytree': 0.43883019458624284, 'gamma': 0.7458545853570875, 'min_child_weight': 3, 'reg_alpha': 0.4689384719633167, 'reg_lambda': 1.905231855629304}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:22:34,090] Trial 44 finished with value: 0.9059234570738995 and parameters: {'n_estimators': 611, 'max_depth': 7, 'learning_rate': 0.048100000000000004, 'subsample': 0.5301294947530487, 'colsample_bytree': 0.4268025169559812, 'gamma': 0.6859186553533193, 'min_child_weight': 4, 'reg_alpha': 0.5373588346145721, 'reg_lambda': 1.8475812286911257}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:22:55,094] Trial 45 finished with value: 0.90560162260773 and parameters: {'n_estimators': 612, 'max_depth': 7, 'learning_rate': 0.048100000000000004, 'subsample': 0.5299913062951772, 'colsample_bytree': 0.42732513469879924, 'gamma': 0.6865816560238492, 'min_child_weight': 4, 'reg_alpha': 0.5117859455223921, 'reg_lambda': 1.6352754090729047}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:23:17,295] Trial 46 finished with value: 0.9057625560280427 and parameters: {'n_estimators': 630, 'max_depth': 8, 'learning_rate': 0.0483, 'subsample': 0.5359605831934371, 'colsample_bytree': 0.41789184701894105, 'gamma': 0.6516261815317365, 'min_child_weight': 4, 'reg_alpha': 0.5329661988503019, 'reg_lambda': 2.0183473483195176}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:23:38,893] Trial 47 finished with value: 0.9046358278391183 and parameters: {'n_estimators': 570, 'max_depth': 7, 'learning_rate': 0.0484, 'subsample': 0.5312505002782101, 'colsample_bytree': 0.4132173978361378, 'gamma': 0.671653622946582, 'min_child_weight': 4, 'reg_alpha': 0.5825896096437996, 'reg_lambda': 2.2425768783196864}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:23:59,605] Trial 48 finished with value: 0.9051991757463526 and parameters: {'n_estimators': 608, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5292123569438938, 'colsample_bytree': 0.42515427590625027, 'gamma': 0.7244864303384867, 'min_child_weight': 1, 'reg_alpha': 0.47650107789310436, 'reg_lambda': 1.8614776811892881}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:24:22,867] Trial 49 finished with value: 0.9049575975563761 and parameters: {'n_estimators': 657, 'max_depth': 7, 'learning_rate': 0.0482, 'subsample': 0.5379241620106547, 'colsample_bytree': 0.43003192162960835, 'gamma': 0.6830884313580069, 'min_child_weight': 2, 'reg_alpha': 0.4356123847900673, 'reg_lambda': 1.7648602568113751}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:24:42,971] Trial 50 finished with value: 0.9056819436328348 and parameters: {'n_estimators': 575, 'max_depth': 6, 'learning_rate': 0.0487, 'subsample': 0.5312911648347804, 'colsample_bytree': 0.420171428611087, 'gamma': 0.7026042716426466, 'min_child_weight': 1, 'reg_alpha': 0.4500561153134658, 'reg_lambda': 1.9367177932280941}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:25:04,706] Trial 51 finished with value: 0.9056015254843622 and parameters: {'n_estimators': 628, 'max_depth': 8, 'learning_rate': 0.0483, 'subsample': 0.5362135175094006, 'colsample_bytree': 0.4166450165748907, 'gamma': 0.6534757781267695, 'min_child_weight': 4, 'reg_alpha': 0.5416296779909087, 'reg_lambda': 2.024388191958349}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:25:26,248] Trial 52 finished with value: 0.9051992081208086 and parameters: {'n_estimators': 600, 'max_depth': 8, 'learning_rate': 0.048, 'subsample': 0.5351184840259969, 'colsample_bytree': 0.4104742763434574, 'gamma': 0.6374904030322652, 'min_child_weight': 4, 'reg_alpha': 0.5668082760540835, 'reg_lambda': 1.9861324202965764}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:25:47,149] Trial 53 finished with value: 0.9043138638751251 and parameters: {'n_estimators': 634, 'max_depth': 5, 'learning_rate': 0.0485, 'subsample': 0.5365455034019835, 'colsample_bytree': 0.4387606954427392, 'gamma': 0.6656505277069843, 'min_child_weight': 3, 'reg_alpha': 0.5338392661503316, 'reg_lambda': 2.077931473402019}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:26:11,607] Trial 54 finished with value: 0.9053601091666653 and parameters: {'n_estimators': 665, 'max_depth': 8, 'learning_rate': 0.048100000000000004, 'subsample': 0.533894813721301, 'colsample_bytree': 0.4190387846773223, 'gamma': 0.6505334703396588, 'min_child_weight': 4, 'reg_alpha': 0.5058683335902717, 'reg_lambda': 1.8295690218667393}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:26:32,969] Trial 55 finished with value: 0.9050382747004957 and parameters: {'n_estimators': 619, 'max_depth': 8, 'learning_rate': 0.0482, 'subsample': 0.5285320875629544, 'colsample_bytree': 0.40785107216383676, 'gamma': 0.7201115001997025, 'min_child_weight': 4, 'reg_alpha': 0.5557222366847184, 'reg_lambda': 1.9253554292613633}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:26:53,066] Trial 56 finished with value: 0.9054405596895936 and parameters: {'n_estimators': 594, 'max_depth': 7, 'learning_rate': 0.0483, 'subsample': 0.5303182561511204, 'colsample_bytree': 0.4261403832143081, 'gamma': 0.6948822685196224, 'min_child_weight': 4, 'reg_alpha': 0.3715358147833407, 'reg_lambda': 2.154797001018977}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:27:15,212] Trial 57 finished with value: 0.9053601091666653 and parameters: {'n_estimators': 585, 'max_depth': 7, 'learning_rate': 0.0484, 'subsample': 0.53330515078557, 'colsample_bytree': 0.4132688336995427, 'gamma': 0.6082841719010998, 'min_child_weight': 1, 'reg_alpha': 0.40742231130002454, 'reg_lambda': 1.4223462843896186}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:27:38,060] Trial 58 finished with value: 0.905279593894825 and parameters: {'n_estimators': 647, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5355463746611046, 'colsample_bytree': 0.4177963333444957, 'gamma': 0.6784382471043956, 'min_child_weight': 1, 'reg_alpha': 0.46298712033179423, 'reg_lambda': 2.052459080629996}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:27:57,918] Trial 59 finished with value: 0.9052796262692808 and parameters: {'n_estimators': 576, 'max_depth': 7, 'learning_rate': 0.048, 'subsample': 0.5345514845000103, 'colsample_bytree': 0.42236802274979635, 'gamma': 0.6400450837560566, 'min_child_weight': 4, 'reg_alpha': 0.5267895951034445, 'reg_lambda': 1.9830863162283445}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:28:21,408] Trial 60 finished with value: 0.9044749267932615 and parameters: {'n_estimators': 642, 'max_depth': 7, 'learning_rate': 0.0484, 'subsample': 0.5256903778533678, 'colsample_bytree': 0.4977431233415533, 'gamma': 0.6240444718731436, 'min_child_weight': 1, 'reg_alpha': 0.5881615244548695, 'reg_lambda': 2.140634200220824}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:28:42,168] Trial 61 finished with value: 0.9056819760072907 and parameters: {'n_estimators': 624, 'max_depth': 7, 'learning_rate': 0.0479, 'subsample': 0.5267019841969504, 'colsample_bytree': 0.43235461373368445, 'gamma': 0.749120367668085, 'min_child_weight': 3, 'reg_alpha': 0.540717176763436, 'reg_lambda': 1.8833724362387947}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:29:04,642] Trial 62 finished with value: 0.9047163431109586 and parameters: {'n_estimators': 621, 'max_depth': 7, 'learning_rate': 0.048100000000000004, 'subsample': 0.527664202488375, 'colsample_bytree': 0.4368594966043085, 'gamma': 0.7535751625940413, 'min_child_weight': 3, 'reg_alpha': 0.5594160890475942, 'reg_lambda': 1.6621080486375417}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:29:27,996] Trial 63 finished with value: 0.9053601091666653 and parameters: {'n_estimators': 631, 'max_depth': 7, 'learning_rate': 0.048, 'subsample': 0.5289781625822274, 'colsample_bytree': 0.4329164433099884, 'gamma': 0.7747132750709697, 'min_child_weight': 4, 'reg_alpha': 0.5170696659270798, 'reg_lambda': 2.578567497232103}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:29:48,196] Trial 64 finished with value: 0.9056819760072907 and parameters: {'n_estimators': 613, 'max_depth': 7, 'learning_rate': 0.0482, 'subsample': 0.5247253961957502, 'colsample_bytree': 0.4305956060704032, 'gamma': 0.7326771132117269, 'min_child_weight': 4, 'reg_alpha': 0.5775192003455002, 'reg_lambda': 1.7667923177012443}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:30:10,447] Trial 65 finished with value: 0.9047162783620468 and parameters: {'n_estimators': 606, 'max_depth': 7, 'learning_rate': 0.0483, 'subsample': 0.5297315591020483, 'colsample_bytree': 0.48366408061680927, 'gamma': 0.7127256056998807, 'min_child_weight': 2, 'reg_alpha': 0.49521697851186336, 'reg_lambda': 2.385150123011898}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:30:32,269] Trial 66 finished with value: 0.9049576623052878 and parameters: {'n_estimators': 618, 'max_depth': 6, 'learning_rate': 0.0478, 'subsample': 0.5197987816550089, 'colsample_bytree': 0.4228021532717333, 'gamma': 0.6640788847700179, 'min_child_weight': 1, 'reg_alpha': 0.5341163020945582, 'reg_lambda': 2.2238347748550833}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:30:53,785] Trial 67 finished with value: 0.9041528333314449 and parameters: {'n_estimators': 627, 'max_depth': 7, 'learning_rate': 0.0478, 'subsample': 0.5316706313578157, 'colsample_bytree': 0.44723082719513646, 'gamma': 0.6963991835420531, 'min_child_weight': 3, 'reg_alpha': 0.47146305182289505, 'reg_lambda': 2.3233968840394}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:31:16,342] Trial 68 finished with value: 0.9053600767922093 and parameters: {'n_estimators': 637, 'max_depth': 5, 'learning_rate': 0.0482, 'subsample': 0.5306333679175833, 'colsample_bytree': 0.4664349436900499, 'gamma': 0.6731366997278689, 'min_child_weight': 1, 'reg_alpha': 0.4846711061707769, 'reg_lambda': 1.9453202603219468}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:31:39,782] Trial 69 finished with value: 0.9060844228686682 and parameters: {'n_estimators': 609, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5371140021511543, 'colsample_bytree': 0.4280882486885512, 'gamma': 0.658580808896832, 'min_child_weight': 2, 'reg_alpha': 0.45738692451552976, 'reg_lambda': 1.808916226396735}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:32:00,529] Trial 70 finished with value: 0.9060038752223722 and parameters: {'n_estimators': 594, 'max_depth': 8, 'learning_rate': 0.0487, 'subsample': 0.5370535923707737, 'colsample_bytree': 0.413851614202905, 'gamma': 0.6581176916929335, 'min_child_weight': 2, 'reg_alpha': 0.424851825350282, 'reg_lambda': 1.8118117799651998}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:32:22,146] Trial 71 finished with value: 0.9053601091666653 and parameters: {'n_estimators': 588, 'max_depth': 8, 'learning_rate': 0.0487, 'subsample': 0.5371014168708443, 'colsample_bytree': 0.41463097375804975, 'gamma': 0.6444806897004116, 'min_child_weight': 2, 'reg_alpha': 0.45451113600894366, 'reg_lambda': 1.8114264483021154}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:32:43,160] Trial 72 finished with value: 0.9052794967714574 and parameters: {'n_estimators': 595, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5365067354257881, 'colsample_bytree': 0.4108668090793108, 'gamma': 0.6567267763247537, 'min_child_weight': 2, 'reg_alpha': 0.4250940578992116, 'reg_lambda': 1.736848168057597}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:33:05,393] Trial 73 finished with value: 0.9053600767922093 and parameters: {'n_estimators': 602, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5376327223101307, 'colsample_bytree': 0.41979047090930044, 'gamma': 0.6317309063882981, 'min_child_weight': 2, 'reg_alpha': 0.39171338458272054, 'reg_lambda': 1.8589637859871107}. Best is trial 32 with value: 0.9061648086426848.
# [I 2025-10-25 05:33:27,448] Trial 74 finished with value: 0.9065671583806945 and parameters: {'n_estimators': 608, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5359662317597962, 'colsample_bytree': 0.4281111570753783, 'gamma': 0.6832972204951421, 'min_child_weight': 1, 'reg_alpha': 0.41143501741282684, 'reg_lambda': 2.0008186074587306}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:33:48,432] Trial 75 finished with value: 0.906245259165613 and parameters: {'n_estimators': 609, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5370882073743664, 'colsample_bytree': 0.42809635229336185, 'gamma': 0.6870030709443059, 'min_child_weight': 1, 'reg_alpha': 0.4364061943904127, 'reg_lambda': 1.7973845000727253}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:34:12,312] Trial 76 finished with value: 0.9055208807146984 and parameters: {'n_estimators': 608, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5369671604469792, 'colsample_bytree': 0.42882505447321223, 'gamma': 0.6847989093551679, 'min_child_weight': 1, 'reg_alpha': 0.4131535450668969, 'reg_lambda': 1.5709230416619586}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:34:34,443] Trial 77 finished with value: 0.9048771146589918 and parameters: {'n_estimators': 594, 'max_depth': 8, 'learning_rate': 0.0487, 'subsample': 0.5371860464082967, 'colsample_bytree': 0.4409858672701452, 'gamma': 0.6989947864357612, 'min_child_weight': 1, 'reg_alpha': 0.3924294528118153, 'reg_lambda': 1.7867091756325988}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:34:55,153] Trial 78 finished with value: 0.9054405596895936 and parameters: {'n_estimators': 603, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5379820160049994, 'colsample_bytree': 0.42627667657562596, 'gamma': 0.7137182309434028, 'min_child_weight': 1, 'reg_alpha': 0.43039808929518736, 'reg_lambda': 1.6914646818444456}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:35:17,094] Trial 79 finished with value: 0.9059233275760759 and parameters: {'n_estimators': 597, 'max_depth': 8, 'learning_rate': 0.0488, 'subsample': 0.5348385949804298, 'colsample_bytree': 0.4365655733809182, 'gamma': 0.6896738578330681, 'min_child_weight': 1, 'reg_alpha': 0.44569480796227673, 'reg_lambda': 1.7298003591183757}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:35:39,120] Trial 80 finished with value: 0.906245323914525 and parameters: {'n_estimators': 611, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5356890510964558, 'colsample_bytree': 0.4235964569542191, 'gamma': 0.6725550652102138, 'min_child_weight': 2, 'reg_alpha': 0.37115455155332566, 'reg_lambda': 1.8376400483087627}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:36:00,270] Trial 81 finished with value: 0.905279626269281 and parameters: {'n_estimators': 610, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5355652353881392, 'colsample_bytree': 0.4248362222369372, 'gamma': 0.6706198731148528, 'min_child_weight': 2, 'reg_alpha': 0.33776015540393245, 'reg_lambda': 1.8401919413329537}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:36:22,499] Trial 82 finished with value: 0.9054405920640496 and parameters: {'n_estimators': 606, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.535980791345487, 'colsample_bytree': 0.4285103402804067, 'gamma': 0.6610672291135876, 'min_child_weight': 2, 'reg_alpha': 0.4033056944517973, 'reg_lambda': 1.9550133051272907}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:36:45,485] Trial 83 finished with value: 0.9049576946797439 and parameters: {'n_estimators': 615, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5333157789864976, 'colsample_bytree': 0.4227573599915355, 'gamma': 0.7287955339385176, 'min_child_weight': 2, 'reg_alpha': 0.3657881801672357, 'reg_lambda': 1.9074072915274776}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:37:06,210] Trial 84 finished with value: 0.9060038104734602 and parameters: {'n_estimators': 600, 'max_depth': 8, 'learning_rate': 0.0487, 'subsample': 0.5361409166783898, 'colsample_bytree': 0.43013778762583205, 'gamma': 0.7030829465213521, 'min_child_weight': 1, 'reg_alpha': 0.4187289711303121, 'reg_lambda': 1.8103123090994189}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:37:27,887] Trial 85 finished with value: 0.9060039075968278 and parameters: {'n_estimators': 600, 'max_depth': 8, 'learning_rate': 0.0487, 'subsample': 0.5366759520400127, 'colsample_bytree': 0.4271611349571963, 'gamma': 0.6790723611324195, 'min_child_weight': 2, 'reg_alpha': 0.4172337129762158, 'reg_lambda': 1.8004969336986267}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:37:48,967] Trial 86 finished with value: 0.9057623941557631 and parameters: {'n_estimators': 601, 'max_depth': 8, 'learning_rate': 0.0487, 'subsample': 0.5366465544960283, 'colsample_bytree': 0.4361017958487525, 'gamma': 0.6804880345290054, 'min_child_weight': 2, 'reg_alpha': 0.4208934687492055, 'reg_lambda': 1.6704873519778707}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:38:10,611] Trial 87 finished with value: 0.9056014931099063 and parameters: {'n_estimators': 590, 'max_depth': 8, 'learning_rate': 0.049, 'subsample': 0.5343484918756851, 'colsample_bytree': 0.43236700044765103, 'gamma': 0.7190455815938249, 'min_child_weight': 2, 'reg_alpha': 0.3798659916959418, 'reg_lambda': 1.7909418348298995}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:38:32,064] Trial 88 finished with value: 0.9053599472943858 and parameters: {'n_estimators': 598, 'max_depth': 8, 'learning_rate': 0.0488, 'subsample': 0.5351764820789974, 'colsample_bytree': 0.4246220858758263, 'gamma': 0.7008133747915923, 'min_child_weight': 2, 'reg_alpha': 0.3545259627491155, 'reg_lambda': 1.601968444165075}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:38:53,158] Trial 89 finished with value: 0.906245259165613 and parameters: {'n_estimators': 614, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5374686422241143, 'colsample_bytree': 0.4210130641534151, 'gamma': 0.707204493725976, 'min_child_weight': 1, 'reg_alpha': 0.39814670859023643, 'reg_lambda': 1.761743621224076}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:39:16,464] Trial 90 finished with value: 0.9059232952016201 and parameters: {'n_estimators': 607, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5374328908365348, 'colsample_bytree': 0.4212315845829493, 'gamma': 0.7068207114986229, 'min_child_weight': 2, 'reg_alpha': 0.39703460982544975, 'reg_lambda': 1.7485516918315362}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:39:38,309] Trial 91 finished with value: 0.9065670936317826 and parameters: {'n_estimators': 613, 'max_depth': 8, 'learning_rate': 0.0487, 'subsample': 0.5361960287387985, 'colsample_bytree': 0.43059218378299996, 'gamma': 0.6744172329400875, 'min_child_weight': 1, 'reg_alpha': 0.3831614877090447, 'reg_lambda': 1.8063442622031154}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:39:59,695] Trial 92 finished with value: 0.9060842933708445 and parameters: {'n_estimators': 614, 'max_depth': 8, 'learning_rate': 0.0487, 'subsample': 0.5362851351298288, 'colsample_bytree': 0.4306650990524172, 'gamma': 0.675476655786261, 'min_child_weight': 1, 'reg_alpha': 0.415656123313408, 'reg_lambda': 1.7161837364455943}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:40:22,015] Trial 93 finished with value: 0.9059232952016201 and parameters: {'n_estimators': 615, 'max_depth': 8, 'learning_rate': 0.0488, 'subsample': 0.5367868276891378, 'colsample_bytree': 0.42845759537698475, 'gamma': 0.67122333025122, 'min_child_weight': 1, 'reg_alpha': 0.3789960255554654, 'reg_lambda': 1.7156228701390324}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:40:43,172] Trial 94 finished with value: 0.9058428446786916 and parameters: {'n_estimators': 604, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5356800199843876, 'colsample_bytree': 0.4351623489560182, 'gamma': 0.6778213165834791, 'min_child_weight': 1, 'reg_alpha': 0.40751361624013693, 'reg_lambda': 1.6378541143175163}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:41:05,097] Trial 95 finished with value: 0.9060842933708445 and parameters: {'n_estimators': 613, 'max_depth': 8, 'learning_rate': 0.0487, 'subsample': 0.5362472577815267, 'colsample_bytree': 0.42426933160617436, 'gamma': 0.6936235445580692, 'min_child_weight': 1, 'reg_alpha': 0.4373123667748772, 'reg_lambda': 1.6890902585886827}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:41:27,242] Trial 96 finished with value: 0.9063257420629973 and parameters: {'n_estimators': 621, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5349889437779033, 'colsample_bytree': 0.42391769676689406, 'gamma': 0.6903252830726064, 'min_child_weight': 1, 'reg_alpha': 0.43731090741712525, 'reg_lambda': 1.6997418770239852}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:41:48,306] Trial 97 finished with value: 0.9059232628271641 and parameters: {'n_estimators': 617, 'max_depth': 8, 'learning_rate': 0.0491, 'subsample': 0.5348882975799951, 'colsample_bytree': 0.42405385632766257, 'gamma': 0.6911843476217865, 'min_child_weight': 1, 'reg_alpha': 0.43224957119478985, 'reg_lambda': 1.5947033836104274}. Best is trial 74 with value: 0.9065671583806945.
# [I 2025-10-25 05:42:11,066] Trial 98 finished with value: 0.9067280594265513 and parameters: {'n_estimators': 621, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5363397929472692, 'colsample_bytree': 0.4205708740303927, 'gamma': 0.665749684703396, 'min_child_weight': 1, 'reg_alpha': 0.3571960328702776, 'reg_lambda': 1.6819505187237385}. Best is trial 98 with value: 0.9067280594265513.
# [I 2025-10-25 05:42:33,507] Trial 99 finished with value: 0.9052794643970014 and parameters: {'n_estimators': 619, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5341393017672151, 'colsample_bytree': 0.43150611824181845, 'gamma': 0.6655692568314504, 'min_child_weight': 1, 'reg_alpha': 0.3574070760321623, 'reg_lambda': 1.5378128655132302}. Best is trial 98 with value: 0.9067280594265513.
# [I 2025-10-25 05:42:54,997] Trial 100 finished with value: 0.9057623294068513 and parameters: {'n_estimators': 621, 'max_depth': 8, 'learning_rate': 0.0494, 'subsample': 0.535313477664723, 'colsample_bytree': 0.4213574871301956, 'gamma': 0.6461312145848194, 'min_child_weight': 1, 'reg_alpha': 0.38304094384355303, 'reg_lambda': 1.6468816580286667}. Best is trial 98 with value: 0.9067280594265513.
# [I 2025-10-25 05:43:17,397] Trial 101 finished with value: 0.9070499262671767 and parameters: {'n_estimators': 613, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5361258990933202, 'colsample_bytree': 0.4202574530998547, 'gamma': 0.6960447227120431, 'min_child_weight': 1, 'reg_alpha': 0.326257522521303, 'reg_lambda': 1.6911045507957159}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:43:39,536] Trial 102 finished with value: 0.9056014283609948 and parameters: {'n_estimators': 609, 'max_depth': 8, 'learning_rate': 0.049, 'subsample': 0.537631736870391, 'colsample_bytree': 0.4168745417022845, 'gamma': 0.6851171080400773, 'min_child_weight': 1, 'reg_alpha': 0.3008464415255432, 'reg_lambda': 1.7111748955643309}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:44:00,280] Trial 103 finished with value: 0.9060037780990043 and parameters: {'n_estimators': 613, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5359014367615055, 'colsample_bytree': 0.41847169774192683, 'gamma': 0.7399666760703676, 'min_child_weight': 1, 'reg_alpha': 0.32668627985231585, 'reg_lambda': 1.7581061175927346}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:44:23,726] Trial 104 finished with value: 0.9060842933708445 and parameters: {'n_estimators': 622, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5335918283361125, 'colsample_bytree': 0.42100962100290507, 'gamma': 0.7168305172453606, 'min_child_weight': 1, 'reg_alpha': 0.3065636672910225, 'reg_lambda': 1.6181649829789289}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:44:46,118] Trial 105 finished with value: 0.9059232304527083 and parameters: {'n_estimators': 616, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5363697470419518, 'colsample_bytree': 0.4261419611648342, 'gamma': 0.6735236078223187, 'min_child_weight': 1, 'reg_alpha': 0.33398712016305815, 'reg_lambda': 1.8784030132241039}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:45:07,380] Trial 106 finished with value: 0.9048771470334476 and parameters: {'n_estimators': 625, 'max_depth': 8, 'learning_rate': 0.0491, 'subsample': 0.5373704641792468, 'colsample_bytree': 0.4332959568522579, 'gamma': 0.708399020970863, 'min_child_weight': 1, 'reg_alpha': 0.3487408024108425, 'reg_lambda': 1.6656658571162801}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:45:29,693] Trial 107 finished with value: 0.9059232628271641 and parameters: {'n_estimators': 611, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5349362131979972, 'colsample_bytree': 0.43046217038880064, 'gamma': 0.6896261204704561, 'min_child_weight': 1, 'reg_alpha': 0.3702827013304011, 'reg_lambda': 1.776602728074846}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:45:52,510] Trial 108 finished with value: 0.9050381128282161 and parameters: {'n_estimators': 605, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5356950703106924, 'colsample_bytree': 0.44046890730514304, 'gamma': 0.6677224929571259, 'min_child_weight': 1, 'reg_alpha': 0.3642611347820175, 'reg_lambda': 1.7014112146697211}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:46:14,208] Trial 109 finished with value: 0.9048771794079036 and parameters: {'n_estimators': 620, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5345114409819904, 'colsample_bytree': 0.4436731812209933, 'gamma': 0.696402783951235, 'min_child_weight': 1, 'reg_alpha': 0.4613003573171573, 'reg_lambda': 1.7432192603043066}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:46:37,214] Trial 110 finished with value: 0.9050380480793045 and parameters: {'n_estimators': 609, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.535379549213119, 'colsample_bytree': 0.4784803127576417, 'gamma': 0.6606165332251706, 'min_child_weight': 1, 'reg_alpha': 0.4485255723796288, 'reg_lambda': 1.8385026487673704}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:46:59,446] Trial 111 finished with value: 0.906164711519317 and parameters: {'n_estimators': 613, 'max_depth': 8, 'learning_rate': 0.0486, 'subsample': 0.5363005703831999, 'colsample_bytree': 0.4233189177889453, 'gamma': 0.6936553014212536, 'min_child_weight': 1, 'reg_alpha': 0.436715674371968, 'reg_lambda': 1.6879017513769647}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:47:21,584] Trial 112 finished with value: 0.9066476089036228 and parameters: {'n_estimators': 613, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5362821813401227, 'colsample_bytree': 0.42786287360099134, 'gamma': 0.682461665023589, 'min_child_weight': 1, 'reg_alpha': 0.39916678165509006, 'reg_lambda': 1.7241225994179572}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:47:44,145] Trial 113 finished with value: 0.9059233599505319 and parameters: {'n_estimators': 617, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.5369541816100148, 'colsample_bytree': 0.4157589958186159, 'gamma': 0.6839521042474621, 'min_child_weight': 1, 'reg_alpha': 0.3995887955806529, 'reg_lambda': 1.6681871675081663}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:48:06,894] Trial 114 finished with value: 0.9064866431088543 and parameters: {'n_estimators': 610, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5326583956180527, 'colsample_bytree': 0.41992615905621283, 'gamma': 0.7015865108990942, 'min_child_weight': 1, 'reg_alpha': 0.4416323805544363, 'reg_lambda': 1.7526798520498543}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:48:29,846] Trial 115 finished with value: 0.9064867078577661 and parameters: {'n_estimators': 623, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5327654791968439, 'colsample_bytree': 0.419875736397984, 'gamma': 0.7023646436446455, 'min_child_weight': 1, 'reg_alpha': 0.37579914281678695, 'reg_lambda': 1.4911612647703625}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:48:51,770] Trial 116 finished with value: 0.9056015254843623 and parameters: {'n_estimators': 627, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5326403635451156, 'colsample_bytree': 0.4197175655404092, 'gamma': 0.7051525692427215, 'min_child_weight': 1, 'reg_alpha': 0.3828840784073006, 'reg_lambda': 1.4816668310444234}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:49:14,032] Trial 117 finished with value: 0.9061647762682288 and parameters: {'n_estimators': 624, 'max_depth': 8, 'learning_rate': 0.0483, 'subsample': 0.5337510426542417, 'colsample_bytree': 0.4175327917469143, 'gamma': 0.7110242391217265, 'min_child_weight': 1, 'reg_alpha': 0.37666190630372215, 'reg_lambda': 1.4649273356240744}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:49:35,169] Trial 118 finished with value: 0.9058427475553238 and parameters: {'n_estimators': 619, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5347055002613331, 'colsample_bytree': 0.4221665828789439, 'gamma': 0.72539552467873, 'min_child_weight': 1, 'reg_alpha': 0.3599540315418116, 'reg_lambda': 1.5484960353771027}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 05:49:58,932] Trial 119 finished with value: 0.9056015254843622 and parameters: {'n_estimators': 622, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5328844513065482, 'colsample_bytree': 0.425976450825073, 'gamma': 0.6995943639153243, 'min_child_weight': 1, 'reg_alpha': 0.34247167469745726, 'reg_lambda': 1.5802417115577883}. Best is trial 101 with value: 0.9070499262671767.
# ...
# [I 2025-10-25 06:15:29,720] Trial 192 finished with value: 0.905681846509467 and parameters: {'n_estimators': 609, 'max_depth': 8, 'learning_rate': 0.0491, 'subsample': 0.5377481018609437, 'colsample_bytree': 0.42184902311752775, 'gamma': 0.8846703945111176, 'min_child_weight': 1, 'reg_alpha': 0.375379642760554, 'reg_lambda': 1.4915393025597632}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:15:50,872] Trial 193 finished with value: 0.90640616021147 and parameters: {'n_estimators': 603, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.536907603244361, 'colsample_bytree': 0.427985007641896, 'gamma': 0.8886270196613054, 'min_child_weight': 1, 'reg_alpha': 0.39231481127478424, 'reg_lambda': 1.6278197047179643}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:16:10,428] Trial 194 finished with value: 0.9063256125651737 and parameters: {'n_estimators': 602, 'max_depth': 8, 'learning_rate': 0.0488, 'subsample': 0.5379997314699162, 'colsample_bytree': 0.4278602920147201, 'gamma': 0.888272771353319, 'min_child_weight': 1, 'reg_alpha': 0.3942411238654935, 'reg_lambda': 1.5427870319142565}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:16:32,815] Trial 195 finished with value: 0.9059232628271641 and parameters: {'n_estimators': 615, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5369842229148749, 'colsample_bytree': 0.429012677510258, 'gamma': 0.8755483945753562, 'min_child_weight': 1, 'reg_alpha': 0.4077760151626233, 'reg_lambda': 1.5697982134654493}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:16:53,344] Trial 196 finished with value: 0.9058428123042356 and parameters: {'n_estimators': 605, 'max_depth': 8, 'learning_rate': 0.049, 'subsample': 0.537371558843434, 'colsample_bytree': 0.43189334058797535, 'gamma': 0.8803764096630659, 'min_child_weight': 1, 'reg_alpha': 0.39004887580470116, 'reg_lambda': 1.6209405372801866}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:17:13,144] Trial 197 finished with value: 0.9068890899702318 and parameters: {'n_estimators': 608, 'max_depth': 8, 'learning_rate': 0.0491, 'subsample': 0.5366428969210872, 'colsample_bytree': 0.424124371213665, 'gamma': 0.8906268586129995, 'min_child_weight': 1, 'reg_alpha': 0.3989755599776492, 'reg_lambda': 1.5220409712516347}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:17:33,732] Trial 198 finished with value: 0.9061647762682288 and parameters: {'n_estimators': 609, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5367346234259489, 'colsample_bytree': 0.4264074398197387, 'gamma': 0.8929520482216807, 'min_child_weight': 1, 'reg_alpha': 0.39962285496539907, 'reg_lambda': 1.5490515886222502}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:17:53,344] Trial 199 finished with value: 0.9061647762682288 and parameters: {'n_estimators': 612, 'max_depth': 8, 'learning_rate': 0.0492, 'subsample': 0.537536640675157, 'colsample_bytree': 0.42446166820390324, 'gamma': 0.8878262543208232, 'min_child_weight': 1, 'reg_alpha': 0.40452156616444646, 'reg_lambda': 1.5150716527392751}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:18:13,919] Trial 200 finished with value: 0.9060843257453003 and parameters: {'n_estimators': 607, 'max_depth': 8, 'learning_rate': 0.0491, 'subsample': 0.5363751057564846, 'colsample_bytree': 0.42421012791981527, 'gamma': 0.8813408598725228, 'min_child_weight': 1, 'reg_alpha': 0.415756607343428, 'reg_lambda': 1.5195099437164696}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:18:33,746] Trial 201 finished with value: 0.9060842933708445 and parameters: {'n_estimators': 616, 'max_depth': 8, 'learning_rate': 0.049, 'subsample': 0.5368100954457775, 'colsample_bytree': 0.42084768035611103, 'gamma': 0.8708366223544788, 'min_child_weight': 1, 'reg_alpha': 0.39362973195130857, 'reg_lambda': 1.5877747818954073}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:18:54,711] Trial 202 finished with value: 0.9057623941557631 and parameters: {'n_estimators': 623, 'max_depth': 8, 'learning_rate': 0.0491, 'subsample': 0.5308321293262858, 'colsample_bytree': 0.42597638117563136, 'gamma': 0.8891879078078467, 'min_child_weight': 1, 'reg_alpha': 0.3827100364042732, 'reg_lambda': 1.4893683330724548}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:19:15,288] Trial 203 finished with value: 0.9059232628271641 and parameters: {'n_estimators': 610, 'max_depth': 8, 'learning_rate': 0.049, 'subsample': 0.5361596705078776, 'colsample_bytree': 0.42239902053714073, 'gamma': 0.894837920699677, 'min_child_weight': 1, 'reg_alpha': 0.3655781762154787, 'reg_lambda': 1.8336332494059158}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:19:36,734] Trial 204 finished with value: 0.905681846509467 and parameters: {'n_estimators': 603, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5371363777736752, 'colsample_bytree': 0.4281911199853841, 'gamma': 0.7718190621075135, 'min_child_weight': 1, 'reg_alpha': 0.39825607459968976, 'reg_lambda': 1.753959233103673}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:19:56,657] Trial 205 finished with value: 0.9058428123042356 and parameters: {'n_estimators': 614, 'max_depth': 8, 'learning_rate': 0.0491, 'subsample': 0.5364134365515119, 'colsample_bytree': 0.4193676960214529, 'gamma': 0.8765298566503941, 'min_child_weight': 1, 'reg_alpha': 0.3899310216800409, 'reg_lambda': 1.8077224326657202}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:20:18,600] Trial 206 finished with value: 0.9062452267911573 and parameters: {'n_estimators': 606, 'max_depth': 8, 'learning_rate': 0.0484, 'subsample': 0.5355752312402761, 'colsample_bytree': 0.4237446741506894, 'gamma': 0.6821894312683733, 'min_child_weight': 1, 'reg_alpha': 0.4310217569122983, 'reg_lambda': 1.7190969682981063}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:20:40,528] Trial 207 finished with value: 0.9061647438937728 and parameters: {'n_estimators': 618, 'max_depth': 8, 'learning_rate': 0.049, 'subsample': 0.5359244254456371, 'colsample_bytree': 0.420112045446832, 'gamma': 0.6959316915189205, 'min_child_weight': 1, 'reg_alpha': 0.45300778972993827, 'reg_lambda': 1.6326842481700448}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:21:00,307] Trial 208 finished with value: 0.9064062897092935 and parameters: {'n_estimators': 611, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5367776026150105, 'colsample_bytree': 0.42973294209122975, 'gamma': 0.8804609733892612, 'min_child_weight': 1, 'reg_alpha': 0.4097755040460992, 'reg_lambda': 1.4400922299490744}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:21:21,332] Trial 209 finished with value: 0.9056014607354503 and parameters: {'n_estimators': 613, 'max_depth': 8, 'learning_rate': 0.0488, 'subsample': 0.5376369440621798, 'colsample_bytree': 0.4268524634124215, 'gamma': 0.8847854260276286, 'min_child_weight': 1, 'reg_alpha': 0.2961106619052381, 'reg_lambda': 1.6990658316175338}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:21:41,372] Trial 210 finished with value: 0.906406127837014 and parameters: {'n_estimators': 611, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5368446265006888, 'colsample_bytree': 0.4341211945973318, 'gamma': 0.8805743449681896, 'min_child_weight': 1, 'reg_alpha': 0.40729696208784844, 'reg_lambda': 1.4477383576554592}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:22:03,415] Trial 211 finished with value: 0.9068085746983915 and parameters: {'n_estimators': 610, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5367959334027286, 'colsample_bytree': 0.434780495006559, 'gamma': 0.8761119092054521, 'min_child_weight': 1, 'reg_alpha': 0.4128741713852574, 'reg_lambda': 1.4303007369165246}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:22:23,801] Trial 212 finished with value: 0.9065671583806945 and parameters: {'n_estimators': 610, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5368401385690276, 'colsample_bytree': 0.4343707375395097, 'gamma': 0.8811774605526291, 'min_child_weight': 1, 'reg_alpha': 0.40932899138725803, 'reg_lambda': 1.427685632625136}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:22:44,201] Trial 213 finished with value: 0.9062452267911573 and parameters: {'n_estimators': 609, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5367031611723292, 'colsample_bytree': 0.4380433104375131, 'gamma': 0.8798408937656017, 'min_child_weight': 1, 'reg_alpha': 0.4126509204601749, 'reg_lambda': 1.4134961810365714}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:23:04,986] Trial 214 finished with value: 0.9060843581197563 and parameters: {'n_estimators': 611, 'max_depth': 8, 'learning_rate': 0.0488, 'subsample': 0.5365592015967158, 'colsample_bytree': 0.43458091602224824, 'gamma': 0.8719290947087851, 'min_child_weight': 1, 'reg_alpha': 0.4077245108741762, 'reg_lambda': 1.4339868163192382}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:23:24,696] Trial 215 finished with value: 0.9061646791448611 and parameters: {'n_estimators': 607, 'max_depth': 8, 'learning_rate': 0.0489, 'subsample': 0.5372439669124844, 'colsample_bytree': 0.43440753327334247, 'gamma': 0.8889357396705606, 'min_child_weight': 1, 'reg_alpha': 0.4167678081738532, 'reg_lambda': 1.4410839689389698}. Best is trial 101 with value: 0.9070499262671767.
# [I 2025-10-25 06:23:46,566] Trial 216 finished with value: 0.9062451944167014 and parameters: {'n_estimators': 610, 'max_depth': 8, 'learning_rate': 0.0485, 'subsample': 0.536935445484626, 'colsample_bytree': 0.4317687603368055, 'gamma': 0.8813032897733646, 'min_child_weight': 1, 'reg_alpha': 0.41954538929663376, 'reg_lambda': 1.4135864779729796}. Best is trial 101 with value: 0.9070499262671767.
# [W 2025-10-25 06:23:59,957] Trial 217 failed with parameters: {'n_estimators': 608, 'max_depth': 8, 'learning_rate': 0.0488, 'subsample': 0.5364318271540359, 'colsample_bytree': 0.43277429940752854, 'gamma': 0.8724857398139346, 'min_child_weight': 1, 'reg_alpha': 0.4000508100758224, 'reg_lambda': 1.4749581674193972} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipython-input-232298322.py", line 23, in objective
#     scores = cross_validate(
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py", line 216, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 411, in cross_validate
#     results = parallel(
#               ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/joblib/parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/joblib/parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "/usr/local/lib/python3.12/dist-packages/joblib/parallel.py", line 1800, in _retrieve
#     time.sleep(0.01)
# KeyboardInterrupt
# [W 2025-10-25 06:23:59,961] Trial 217 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2781893490.py in <cell line: 0>()
#      22
#      23
# ---> 24 study.optimize(objective, n_trials=300, show_progress_bar=True)
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     488                 If nested invocation of this method occurs.
#     489         """
# --> 490         _optimize(
#     491             study=self,
#     492             func=func,
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61     try:
#      62         if n_jobs == 1:
# ---> 63             _optimize_sequential(
#      64                 study,
#      65                 func,
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     158
#     159         try:
# --> 160             frozen_trial_id = _run_trial(study, func, catch)
#     161         finally:
#     162             # The following line mitigates memory problems that can be occurred in some
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     256         and not isinstance(func_err, catch)
#     257     ):
# --> 258         raise func_err
#     259     return trial._trial_id
#     260
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     199     with get_heartbeat_thread(trial._trial_id, study._storage):
#     200         try:
# --> 201             value_or_values = func(trial)
#     202         except exceptions.TrialPruned as e:
#     203             # TODO(mamu): Handle multi-objective cases.
#
# /tmp/ipython-input-232298322.py in objective(trial)
#      21     cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
#      22
# ---> 23     scores = cross_validate(
#      24         model,
#      25         X_train,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     409     # independent, and that it is pickle-able.
#     410     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 411     results = parallel(
#     412         delayed(_fit_and_score)(
#     413             clone(estimator),
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#      78
#      79
#
# /usr/local/lib/python3.12/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    2070         next(output)
#    2071
# -> 2072         return output if self.return_generator else list(output)
#    2073
#    2074     def __repr__(self):
#
# /usr/local/lib/python3.12/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1680
#    1681             with self._backend.retrieval_context():
# -> 1682                 yield from self._retrieve()
#    1683
#    1684         except GeneratorExit:
#
# /usr/local/lib/python3.12/dist-packages/joblib/parallel.py in _retrieve(self)
#    1798                     self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799                 ):
# -> 1800                     time.sleep(0.01)
#    1801                     continue
#    1802
#
# KeyboardInterrupt:
